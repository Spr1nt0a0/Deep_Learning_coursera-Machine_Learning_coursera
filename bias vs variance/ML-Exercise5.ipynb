# %% [markdown]
# # 机器学习练习 5 - 偏差和方差

# %% [markdown]
# 本章代码涵盖了基于Python的解决方案，用于Coursera机器学习课程的第五个编程练习。 请参考[练习文本](ex5.pdf)了解详细的说明和公式。
#
# 代码修改并注释：黄海广，haiguang2000@qq.com

# %%
import numpy as np
import scipy.io as sio
import scipy.optimize as opt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data():
    """for ex5
    d['X'] shape = (12, 1)
    pandas has trouble taking this 2d ndarray to construct a dataframe, so I ravel
    the results
    """
    d = sio.loadmat('ex5data1.mat')
    return map(np.ravel, [d['X'], d['y'], d['Xval'], d['yval'], d['Xtest'], d['ytest']])

# %%
X, y, Xval, yval, Xtest, ytest = load_data()

# %%
df = pd.DataFrame({'water_level':X, 'flow':y})

sns.lmplot('water_level', 'flow', data=df, fit_reg=False, size=7)
plt.show()

# %%
X, Xval, Xtest = [np.insert(x.reshape(x.shape[0], 1), 0, np.ones(x.shape[0]), axis=1) for x in (X, Xval, Xtest)]

# %% [markdown]
# # 代价函数
# <img style="float: left;" src="../img/linear_cost.png">

# %%
def cost(theta, X, y):
    """
    X: R(m*n), m records, n features
    y: R(m)
    theta : R(n), linear regression parameters
    """
    m = X.shape[0]

    inner = X @ 1*1 in matrix multiplication
    # but you know numpy didn't do transpose in 1d array, so here is just a
    # vector inner product to itselves
    square_sum = inner.T @ inner
    cost = square_sum / (2 * m)

    return cost
# Out:
#   File "<ipython-input-10-2cae465aea61>", line 9
#     inner = X @ 1*1 in matrix multiplication
#               ^
# SyntaxError: invalid syntax

# %%
theta = np.ones(X.shape[1])
cost(theta, X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ebb241579edb> in <module>()
#       1 theta = np.ones(X.shape[1])
# ----> 2 cost(theta, X, y)
#
# NameError: name 'cost' is not defined

# %% [markdown]
# # 梯度
# <img style="float: left;" src="../img/linear_gradient.png">

# %%
def gradient(theta, X, y):
    m = X.shape[0]

    inner = X.T @ (X @ theta - y)  # (m,n).T @ (m, 1) -> (n, 1)

    return inner / m
# Out:
#   File "<ipython-input-12-855f9e5558a3>", line 4
#     inner = X.T @ (X @ theta - y)  # (m,n).T @ (m, 1) -> (n, 1)
#                 ^
# SyntaxError: invalid syntax

# %%
gradient(theta, X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1aaeaea89479> in <module>()
# ----> 1 gradient(theta, X, y)
#
# NameError: name 'gradient' is not defined

# %% [markdown]
# # 正则化梯度
# <img style="float: left;" src="../img/linear_reg_gradient.png">

# %%
def regularized_gradient(theta, X, y, l=1):
    m = X.shape[0]

    regularized_term = theta.copy()  # same shape as theta
    regularized_term[0] = 0  # don't regularize intercept theta

    regularized_term = (l / m) * regularized_term

    return gradient(theta, X, y) + regularized_term

# %%
regularized_gradient(theta, X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7533626b89c8> in <module>()
# ----> 1 regularized_gradient(theta, X, y)
#
# <ipython-input-14-f396080ab2ff> in regularized_gradient(theta, X, y, l)
#       7     regularized_term = (l / m) * regularized_term
#       8
# ----> 9     return gradient(theta, X, y) + regularized_term
#
# NameError: global name 'gradient' is not defined

# %% [markdown]
# # 拟合数据
# > 正则化项 $\lambda=0$

# %%
def linear_regression_np(X, y, l=1):
    """linear regression
    args:
        X: feature matrix, (m, n+1) # with incercept x0=1
        y: target vector, (m, )
        l: lambda constant for regularization

    return: trained parameters
    """
    # init theta
    theta = np.ones(X.shape[1])

    # train it
    res = opt.minimize(fun=regularized_cost,
                       x0=theta,
                       args=(X, y, l),
                       method='TNC',
                       jac=regularized_gradient,
                       options={'disp': True})
    return res

# %%
def regularized_cost(theta, X, y, l=1):
    m = X.shape[0]

    regularized_term = (l / (2 * m)) * np.power(theta[1:], 2).sum()

    return cost(theta, X, y) + regularized_term

# %%
theta = np.ones(X.shape[0] )

final_theta = linear_regression_np(X, y, l=0).get('x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-e6f31b795995> in <module>()
#       1 theta = np.ones(X.shape[0] )
#       2
# ----> 3 final_theta = linear_regression_np(X, y, l=0).get('x')
#
# <ipython-input-16-0f8f46e255a2> in linear_regression_np(X, y, l)
#      17                        method='TNC',
#      18                        jac=regularized_gradient,
# ---> 19                        options={'disp': True})
#      20     return res
#
# c:\python27\lib\site-packages\scipy\optimize\_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     488     elif meth == 'tnc':
#     489         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
# --> 490                              **options)
#     491     elif meth == 'cobyla':
#     492         return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# c:\python27\lib\site-packages\scipy\optimize\tnc.pyc in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, **unknown_options)
#     407                                         offset, messages, maxCGit, maxfun,
#     408                                         eta, stepmx, accuracy, fmin, ftol,
# --> 409                                         xtol, pgtol, rescale, callback)
#     410
#     411     funv, jacv = func_and_grad(x)
#
# c:\python27\lib\site-packages\scipy\optimize\tnc.pyc in func_and_grad(x)
#     369     else:
#     370         def func_and_grad(x):
# --> 371             f = fun(x, *args)
#     372             g = jac(x, *args)
#     373             return f, g
#
# <ipython-input-17-4cd7ea4c4d95> in regularized_cost(theta, X, y, l)
#       4     regularized_term = (l / (2 * m)) * np.power(theta[1:], 2).sum()
#       5
# ----> 6     return cost(theta, X, y) + regularized_term
#
# NameError: global name 'cost' is not defined

# %%
b = final_theta[0] # intercept
m = final_theta[1] # slope

plt.scatter(X[:,1], y, label="Training data")
plt.plot(X[:, 1], X[:, 1]*m + b, label="Prediction")
plt.legend(loc=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-877486836768> in <module>()
# ----> 1 b = final_theta[0] # intercept
#       2 m = final_theta[1] # slope
#       3
#       4 plt.scatter(X[:,1], y, label="Training data")
#       5 plt.plot(X[:, 1], X[:, 1]*m + b, label="Prediction")
#
# NameError: name 'final_theta' is not defined

# %%
training_cost, cv_cost = [], []

# %% [markdown]
# 1.使用训练集的子集来拟合应模型
#
# 2.在计算训练代价和交叉验证代价时，没有用正则化
#
# 3.记住使用相同的训练集子集来计算训练代价

# %%
m = X.shape[0]
for i in range(1, m+1):
#     print('i={}'.format(i))
    res = linear_regression_np(X[:i, :], y[:i], l=0)
    
    tc = regularized_cost(res.x, X[:i, :], y[:i], l=0)
    cv = regularized_cost(res.x, Xval, yval, l=0)
#     print('tc={}, cv={}'.format(tc, cv))
    
    training_cost.append(tc)
    cv_cost.append(cv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6447ef6f486b> in <module>()
#       2 for i in range(1, m+1):
#       3 #     print('i={}'.format(i))
# ----> 4     res = linear_regression_np(X[:i, :], y[:i], l=0)
#       5
#       6     tc = regularized_cost(res.x, X[:i, :], y[:i], l=0)
#
# <ipython-input-16-0f8f46e255a2> in linear_regression_np(X, y, l)
#      17                        method='TNC',
#      18                        jac=regularized_gradient,
# ---> 19                        options={'disp': True})
#      20     return res
#
# c:\python27\lib\site-packages\scipy\optimize\_minimize.pyc in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     488     elif meth == 'tnc':
#     489         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
# --> 490                              **options)
#     491     elif meth == 'cobyla':
#     492         return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# c:\python27\lib\site-packages\scipy\optimize\tnc.pyc in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, **unknown_options)
#     407                                         offset, messages, maxCGit, maxfun,
#     408                                         eta, stepmx, accuracy, fmin, ftol,
# --> 409                                         xtol, pgtol, rescale, callback)
#     410
#     411     funv, jacv = func_and_grad(x)
#
# c:\python27\lib\site-packages\scipy\optimize\tnc.pyc in func_and_grad(x)
#     369     else:
#     370         def func_and_grad(x):
# --> 371             f = fun(x, *args)
#     372             g = jac(x, *args)
#     373             return f, g
#
# <ipython-input-17-4cd7ea4c4d95> in regularized_cost(theta, X, y, l)
#       4     regularized_term = (l / (2 * m)) * np.power(theta[1:], 2).sum()
#       5
# ----> 6     return cost(theta, X, y) + regularized_term
#
# NameError: global name 'cost' is not defined

# %%
plt.plot(np.arange(1, m+1), training_cost, label='training cost')
plt.plot(np.arange(1, m+1), cv_cost, label='cv cost')
plt.legend(loc=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3cc1502aee67> in <module>()
# ----> 1 plt.plot(np.arange(1, m+1), training_cost, label='training cost')
#       2 plt.plot(np.arange(1, m+1), cv_cost, label='cv cost')
#       3 plt.legend(loc=1)
#       4 plt.show()
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# c:\python27\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# c:\python27\lib\site-packages\matplotlib\axes\_axes.pyc in plot(self, *args, **kwargs)
#    1435         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1436
# -> 1437         for line in self._get_lines(*args, **kwargs):
#    1438             self.add_line(line)
#    1439             lines.append(line)
#
# c:\python27\lib\site-packages\matplotlib\axes\_base.pyc in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# c:\python27\lib\site-packages\matplotlib\axes\_base.pyc in _plot_args(self, tup, kwargs)
#     382             x, y = index_of(tup[-1])
#     383
# --> 384         x, y = self._xy_from_xy(x, y)
#     385
#     386         if self.command == 'plot':
#
# c:\python27\lib\site-packages\matplotlib\axes\_base.pyc in _xy_from_xy(self, x, y)
#     241         if x.shape[0] != y.shape[0]:
#     242             raise ValueError("x and y must have same first dimension, but "
# --> 243                              "have shapes {} and {}".format(x.shape, y.shape))
#     244         if x.ndim > 2 or y.ndim > 2:
#     245             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (12,) and (0,)

# %% [markdown]
# 这个模型拟合不太好, **欠拟合了**

# %% [markdown]
# # 创建多项式特征

# %%
def prepare_poly_data(*args, power):
    """
    args: keep feeding in X, Xval, or Xtest
        will return in the same order
    """
    def prepare(x):
        # expand feature
        df = poly_features(x, power=power)

        # normalization
        ndarr = normalize_feature(df).as_matrix()

        # add intercept term
        return np.insert(ndarr, 0, np.ones(ndarr.shape[0]), axis=1)

    return [prepare(x) for x in args]
# Out:
#   File "<ipython-input-23-bbcbb1b023a2>", line 1
#     def prepare_poly_data(*args, power):
#                                      ^
# SyntaxError: invalid syntax

# %%
def poly_features(x, power, as_ndarray=False):
    data = {'f{}'.format(i): np.power(x, i) for i in range(1, power + 1)}
    df = pd.DataFrame(data)

    return df.as_matrix() if as_ndarray else df

# %%
X, y, Xval, yval, Xtest, ytest = load_data()

# %%
poly_features(X, power=3)
# Out:
#            f1           f2             f3
# 0  -15.936758   253.980260   -4047.621971
# 1  -29.152979   849.896197  -24777.006175
# 2   36.189549  1309.683430   47396.852168
# 3   37.492187  1405.664111   52701.422173
# 4  -48.058829  2309.651088 -110999.127750
# 5   -8.941458    79.949670    -714.866612
# 6   15.307793   234.328523    3587.052500
# 7  -34.706266  1204.524887  -41804.560890
# 8    1.389154     1.929750       2.680720
# 9  -44.383760  1969.918139  -87432.373590
# 10   7.013502    49.189211     344.988637
# 11  22.762749   518.142738   11794.353058

# %% [markdown]
# # 准备多项式回归数据
# 1. 扩展特征到 8阶,或者你需要的阶数
# 2. 使用 **归一化** 来合并 $x^n$
# 3. don't forget intercept term

# %%
def normalize_feature(df):
    """Applies function along input axis(default 0) of DataFrame."""
    return df.apply(lambda column: (column - column.mean()) / column.std())

# %%
X_poly, Xval_poly, Xtest_poly= prepare_poly_data(X, Xval, Xtest, power=8)
X_poly[:3, :]
# Out:
# array([[  1.00000000e+00,  -3.62140776e-01,  -7.55086688e-01,
#           1.82225876e-01,  -7.06189908e-01,   3.06617917e-01,
#          -5.90877673e-01,   3.44515797e-01,  -5.08481165e-01],
#        [  1.00000000e+00,  -8.03204845e-01,   1.25825266e-03,
#          -2.47936991e-01,  -3.27023420e-01,   9.33963187e-02,
#          -4.35817606e-01,   2.55416116e-01,  -4.48912493e-01],
#        [  1.00000000e+00,   1.37746700e+00,   5.84826715e-01,
#           1.24976856e+00,   2.45311974e-01,   9.78359696e-01,
#          -1.21556976e-02,   7.56568484e-01,  -1.70352114e-01]])

# %% [markdown]
# # 画出学习曲线
# > 首先，我们没有使用正则化，所以 $\lambda=0$

# %%
def plot_learning_curve(X, y, Xval, yval, l=0):
    training_cost, cv_cost = [], []
    m = X.shape[0]

    for i in range(1, m + 1):
        # regularization applies here for fitting parameters
        res = linear_regression_np(X[:i, :], y[:i], l=l)

        # remember, when you compute the cost here, you are computing
        # non-regularized cost. Regularization is used to fit parameters only
        tc = cost(res.x, X[:i, :], y[:i])
        cv = cost(res.x, Xval, yval)

        training_cost.append(tc)
        cv_cost.append(cv)

    plt.plot(np.arange(1, m + 1), training_cost, label='training cost')
    plt.plot(np.arange(1, m + 1), cv_cost, label='cv cost')
    plt.legend(loc=1)

# %%
plot_learning_curve(X_poly, y, Xval_poly, yval, l=0)
plt.show()

# %% [markdown]
# 你可以看到训练的代价太低了，不真实. 这是 **过拟合**了

# %% [markdown]
# # try $\lambda=1$

# %%
plot_learning_curve(X_poly, y, Xval_poly, yval, l=1)
plt.show()

# %% [markdown]
# 训练代价增加了些，不再是0了。
# 也就是说我们减轻**过拟合**

# %% [markdown]
# # try $\lambda=100$

# %%
plot_learning_curve(X_poly, y, Xval_poly, yval, l=100)
plt.show()

# %% [markdown]
# 太多正则化了.
# 变成 **欠拟合**状态

# %% [markdown]
# # 找到最佳的 $\lambda$

# %%
l_candidate = [0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10]
training_cost, cv_cost = [], []

# %%
for l in l_candidate:
    res = linear_regression_np(X_poly, y, l)
    
    tc = cost(res.x, X_poly, y)
    cv = cost(res.x, Xval_poly, yval)
    
    training_cost.append(tc)
    cv_cost.append(cv)

# %%
plt.plot(l_candidate, training_cost, label='training')
plt.plot(l_candidate, cv_cost, label='cross validation')
plt.legend(loc=2)

plt.xlabel('lambda')

plt.ylabel('cost')
plt.show()

# %%
# best cv I got from all those candidates
l_candidate[np.argmin(cv_cost)]
# Out:
# 1

# %%
# use test data to compute the cost
for l in l_candidate:
    theta = linear_regression_np(X_poly, y, l).x
    print('test cost(l={}) = {}'.format(l, cost(theta, Xtest_poly, ytest)))
# Out:
# test cost(l=0) = 9.799399498688892
# test cost(l=0.001) = 11.054987989655938
# test cost(l=0.003) = 11.249198861537238
# test cost(l=0.01) = 10.879605199670008
# test cost(l=0.03) = 10.022734920552129
# test cost(l=0.1) = 8.632060998872074
# test cost(l=0.3) = 7.336602384055533
# test cost(l=1) = 7.46630349664086
# test cost(l=3) = 11.643928200535115
# test cost(l=10) = 27.715080216719304

# %% [markdown]
# 调参后， $\lambda = 0.3$ 是最优选择，这个时候测试代价最小
